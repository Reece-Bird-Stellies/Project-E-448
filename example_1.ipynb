# %% [markdown]
# ## Hamiltonian of Example 1

# %%
from quantum_analysis_lom import *
from analyse_hamiltonian import *
from post_processing import *

def print_hamiltonian_analysis(results):
    if not isinstance(results, dict):
        print(results)
        return

    print("\nHamiltonian analysis results:")
    print("-" * 40)
    print(f"Qubit frequency      : {results['qubit_frequency_ghz']:.6f} GHz")
    print(f"Cavity frequency     : {results['cavity_frequency_ghz']:.6f} GHz")
    print(f"Anharmonicity        : {results['anharmonicity_mhz']:.3f} MHz")
    print(f"Coupling g           : {results['coupling_g_mhz']:.3f} MHz")
    print(f"Kappa                : {results['kappa_khz']:.3f} kHz")
    print(f"Hilbert dimension    : {results['h_dimension']}")
    print("-" * 40)

# %%
Nq                      = 10
Nc                      = 10
Nmax                    = 10

# %%
Lj                 = 20.0898e-9
Cj                 = 0   
Cg                 = 9.2280e-15
Cs                 = 142.0020e-15
Lr                 = 1.7520e-9
Cr                 = 778.8991e-15
hamiltonian_lom    = compute_hamiltonian_lom(Lj=Lj, Lr=Lr, Cj=Cj, Cs=Cs, Cg=Cg, Cr=Cr, Nc=Nc, Nq=Nq, Nmax=Nmax)

# %%
results_lom            = analyse_hamilotonian(hamiltonian_lom, Nc, Nq, "LOM")
print_hamiltonian_analysis(results_lom)
# Out:
# Hamiltonian is Hermitian
# Is diagonal? True
# Reconstruction ok? True
# Hamiltonian is Hermitian
# Is diagonal? True
# Reconstruction ok? True
# Hamiltonian is Hermitian
# Is diagonal? True
# Reconstruction ok? True
#
# Hamiltonian analysis results:
# ----------------------------------------
# Qubit frequency      : 2.752882 GHz
# Cavity frequency     : 4.308365 GHz
# Anharmonicity        : -144.337 MHz
# Coupling g           : 46.290 MHz
# Kappa                : 0.000 kHz
# Hilbert dimension    : 100
# ----------------------------------------
